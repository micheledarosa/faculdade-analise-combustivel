# %% [markdown]
# # Aulá prática de análise de dados com Pandas
#
# Importando biblioteca e lendo arquivo

# %%
import pandas as pd 

df = pd.read_csv('combustivel-2023.csv', sep=';', encoding='ISO-8859-1')
display(df)
# Out:
#        ï»¿Regiao - Sigla Estado - Sigla        Municipio  \
# 0                     SE             SP         SOROCABA
# 1                     SE             SP         SOROCABA
# 2                     SE             SP         SOROCABA
# 3                      N             AC  CRUZEIRO DO SUL
# 4                      N             AC  CRUZEIRO DO SUL
# ...                  ...            ...              ...
# 472419                 N             AP          SANTANA
# 472420                 N             AP          SANTANA
# 472421                NE             PI         PARNAIBA
# 472422                NE             PI         PARNAIBA
# 472423                NE             PI         PARNAIBA
#
#                                                   Revenda  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 2       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# ...

# %% [markdown]
# Link: https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/serie-historica-de-precos-de-combustiveis
#
# - 2° semestre de 2023

# %%
df.head()
# Out:
#   ï»¿Regiao - Sigla Estado - Sigla        Municipio  \
# 0                SE             SP         SOROCABA
# 1                SE             SP         SOROCABA
# 2                SE             SP         SOROCABA
# 3                 N             AC  CRUZEIRO DO SUL
# 4                 N             AC  CRUZEIRO DO SUL
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 3                           CARDINAL E OLIVEIRA LTDA   03.608.766/0006-56
# 4                           CARDINAL E OLIVEIRA LTDA   03.608.766/0006-56
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# ...

# %%
df.columns.values
# Out:
# array(['ï»¿Regiao - Sigla', 'Estado - Sigla', 'Municipio', 'Revenda',
#        'CNPJ da Revenda', 'Nome da Rua', 'Numero Rua', 'Complemento',
#        'Bairro', 'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda',
#        'Valor de Compra', 'Unidade de Medida', 'Bandeira'], dtype=object)

# %% [markdown]
# Criando uma variável para utilizar apenas as colunas que quero

# %%
dfColunas = ['Estado - Sigla', 'Municipio', 'Revenda', 
             'Produto', 'Data da Coleta', 'Valor de Venda']

dfFiltrado = df.filter(items=dfColunas)
dfFiltrado
# Out:
#        Estado - Sigla        Municipio  \
# 0                  SP         SOROCABA
# 1                  SP         SOROCABA
# 2                  SP         SOROCABA
# 3                  AC  CRUZEIRO DO SUL
# 4                  AC  CRUZEIRO DO SUL
# ...               ...              ...
# 472419             AP          SANTANA
# 472420             AP          SANTANA
# 472421             PI         PARNAIBA
# 472422             PI         PARNAIBA
# 472423             PI         PARNAIBA
#
#                                                   Revenda             Produto  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...            GASOLINA
# 1       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...          DIESEL S10
# 2       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...              ETANOL
# 3                                CARDINAL E OLIVEIRA LTDA            GASOLINA
# 4                                CARDINAL E OLIVEIRA LTDA          DIESEL S10
# ...

# %% [markdown]
# Alterando o nome da coluna

# %%
dfFiltrado = dfFiltrado.rename(columns={'Estado - Sigla':'Estado'})
dfFiltrado
# Out:
#        Estado        Municipio  \
# 0          SP         SOROCABA
# 1          SP         SOROCABA
# 2          SP         SOROCABA
# 3          AC  CRUZEIRO DO SUL
# 4          AC  CRUZEIRO DO SUL
# ...       ...              ...
# 472419     AP          SANTANA
# 472420     AP          SANTANA
# 472421     PI         PARNAIBA
# 472422     PI         PARNAIBA
# 472423     PI         PARNAIBA
#
#                                                   Revenda             Produto  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...            GASOLINA
# 1       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...          DIESEL S10
# 2       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...              ETANOL
# 3                                CARDINAL E OLIVEIRA LTDA            GASOLINA
# 4                                CARDINAL E OLIVEIRA LTDA          DIESEL S10
# ...                                                   ...                 ...
# ...

# %% [markdown]
# Quantidade de entradas por estado

# %%
colunaEstados = dfFiltrado['Estado']
colunaEstados = colunaEstados.value_counts()  # normalize = True para ver percentual
colunaEstados
# Out:
# Estado
# SP    127722
# MG     51289
# RJ     37094
# RS     34472
# PR     30919
# BA     28792
# SC     19445
# GO     17467
# PE     15502
# CE     14463
# MA     10912
# PA     10305
# ES     10116
# PB      6325
# MT      6212
# MS      6129
# AL      5719
# RO      5625
# AM      5410
# PI      5393
# TO      5009
# RN      4879
# DF      4734
# SE      3446
# AC      2049
# RR      1687
# AP      1309
# Name: count, dtype: int64

# %% [markdown]
# Percentual por Estado

# %%
pEstados = [100*sigla/colunaEstados.sum() for sigla in colunaEstados]
pEstados
# Out:
# [27.03545967182023,
#  10.856561055323183,
#  7.8518449528389755,
#  7.296835046483667,
#  6.544756405263069,
#  6.09452525697255,
#  4.116005960747126,
#  3.6973142770054017,
#  3.281374358626996,
#  3.061444803820297,
#  2.309789511117132,
#  2.1813032360760674,
#  2.141296801178602,
#  1.3388396863834182,
#  1.314920495148426,
#  1.297351531674936,
#  1.2105650856010701,
#  1.190667705281696,
#  1.1451577396575958,
#  1.141559277259411,
#  1.0602763619121807,
#  1.0327587082790035,
#  1.0020659407650754,
#  0.7294294955379066,
#  0.4337205561106125,
#  0.35709447445515047,
#  0.27708160466022047]

# %% [markdown]
# Filtrando somente por gasolina

# %%
dfColunas = ['Estado', 'Produto', 'Valor de Venda']
dfGasolina = dfFiltrado.filter(items=dfColunas)
dfGasolina = dfGasolina.loc[dfGasolina['Produto'] == 'Gasolina'.upper()]
dfGasolina
# Out:
#        Estado   Produto Valor de Venda
# 0          SP  GASOLINA           4,87
# 3          AC  GASOLINA           6,95
# 5          AC  GASOLINA           6,93
# 10         AC  GASOLINA           6,29
# 15         AC  GASOLINA           6,22
# ...       ...       ...            ...
# 472409     MG  GASOLINA           5,29
# 472411     BA  GASOLINA           5,64
# 472415     SP  GASOLINA           4,87
# 472418     AP  GASOLINA           5,75
# 472421     PI  GASOLINA            5,2
#
# [121261 rows x 3 columns]

# %% [markdown]
# Agrupando por preço de gasolina

# %%
dfGasolina['Valor de Venda'] = dfGasolina['Valor de Venda'].str.replace(',','.')
dfGasolina = dfGasolina.astype({'Valor de Venda': 'float32'})
dfGasolina = dfGasolina.groupby('Estado').mean()
dfGasolina
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %% [markdown]
# Dois tipos de gasolina - regex

# %%
dfColunas = ['Estado', 'Produto', 'Valor de Venda']
dfGasolina2 = dfFiltrado.filter(items=dfColunas)
regex = '^GASOLINA'
dfGasolina2 = dfGasolina2.loc[dfGasolina2['Produto'].str.contains(regex, regex=True)]
dfGasolina2
# Out:
#        Estado             Produto Valor de Venda
# 0          SP            GASOLINA           4,87
# 3          AC            GASOLINA           6,95
# 5          AC            GASOLINA           6,93
# 6          AC  GASOLINA ADITIVADA           6,99
# 10         AC            GASOLINA           6,29
# ...       ...                 ...            ...
# 472411     BA            GASOLINA           5,64
# 472415     SP            GASOLINA           4,87
# 472418     AP            GASOLINA           5,75
# 472421     PI            GASOLINA            5,2
# 472422     PI  GASOLINA ADITIVADA            5,2
#
# [216038 rows x 3 columns]

# %% [markdown]
# Agrupando por tipo de gasolina no Brasil inteiro

# %%
dfGasolina2['Valor de Venda'] = dfGasolina2['Valor de Venda'].str.replace(',','.')
dfGasolina2 = dfGasolina2.astype({'Valor de Venda': 'float32'})
dfGasolina2 = dfGasolina2.groupby('Produto').mean()
dfGasolina2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %% [markdown]
# Pandas Profiling

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(dfFiltrado)
profile.to_file('saida.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\misha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ydata_profiling\model\typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# C:\Users\misha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ydata_profiling\model\typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# ...
